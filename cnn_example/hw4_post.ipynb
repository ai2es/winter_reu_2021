# %%
# %reload_ext autoreload
# %autoreload 2

from hw4_post_support import *

# %%
dirname = 'results_hw4'
filebase = 'image_None_hidden_75_30_10_5_Csize_3_3_3_3_3_3_3_3_Cfilters_10_20_30_40_50_60_70_80_Pool_1_2_1_2_1_2_1_2_1_drop_0.50_ntrain_04_rot_*_results.pkl'
visualizeExperiment(dirname, filebase)
# Out:
# Average Val Accuracy:
# 0.4488324850797653
# Example Training Predictions:
# [[0.3332188  0.32609454 0.34068668]
#  [0.33301267 0.32617998 0.34080738]
#  [0.33319774 0.32607502 0.34072718]
#  ...
#  [0.33168063 0.32694963 0.3413697 ]
#  [0.33234712 0.32647833 0.34117457]
#  [0.3323897  0.32648712 0.34112322]]
# Example Validation Predictions:
# [[0.3324987  0.3264994  0.34100184]
#  [0.33313617 0.32612944 0.34073445]
#  [0.3332594  0.3259817  0.3407589 ]
#  ...
#  [0.33260006 0.32636732 0.34103265]
#  [0.33184758 0.32673535 0.34141707]
#  [0.33264056 0.3263174  0.341042  ]]

# %%
dirname = 'results_hw4'
filebase = 'image_None_hidden_75_30_10_5_Csize_3_3_3_3_3_3_3_3_Cfilters_10_20_30_40_50_60_70_80_Pool_1_2_1_2_1_2_1_2_1_drop_0.50_ntrain_04_rot_*_results.pkl'
visualizeConfusion(dirname, filebase)
# Out:
# 0.8462432465928774

# %% [markdown]
# ## Experiment 2

# %%
dirname = 'results_hw4'
filebase = 'image_None_hidden_75_30_10_5_Csize_3_3_3_3_3_3_3_3_Cfilters_10_20_30_40_50_60_70_80_Pool_1_2_1_2_1_2_1_2_drop_0.50_L2_0.000100_ntrain_04_rot_*_results.pkl'
visualizeExperiment(dirname, filebase)
# Out:
# Average Val Accuracy:
# 0.568850189447403
# Example Training Predictions:
# [[0.47629294 0.03058748 0.49311957]
#  [0.5047562  0.03132685 0.463917  ]
#  [0.41827354 0.06102389 0.52070266]
#  ...
#  [0.4022956  0.05418622 0.54351825]
#  [0.4189136  0.05872316 0.52236325]
#  [0.43272248 0.05075165 0.5165259 ]]
# Example Validation Predictions:
# [[0.4010475  0.06576695 0.53318554]
#  [0.4696075  0.09135458 0.43903795]
#  [0.59778184 0.01189547 0.39032272]
#  ...
#  [0.45849386 0.03140375 0.5101024 ]
#  [0.40266827 0.05658573 0.54074603]
#  [0.533511   0.02585358 0.44063544]]

# %%
visualizeConfusion(dirname, filebase)
# Out:
# 0.7360602776952249

# %% [markdown]
# ## Shallow Exp

# %%
dirname = 'results_hw4'
filebase = 'image_None_hidden_50_20_Csize_3_3_3_3_3_Cfilters_10_20_30_40_50_Pool_2_2_2_2_2_drop_0.50_L2_0.000100_ntrain_04_rot_*_results.pkl'
visualizeExperiment(dirname, filebase)
# Out:
# Average Val Accuracy:
# 0.5889140248298645
# Example Training Predictions:
# [[0.41315356 0.18537515 0.40147126]
#  [0.4221894  0.13801321 0.43979743]
#  [0.41910204 0.15097836 0.42991963]
#  ...
#  [0.39402872 0.16057871 0.4453926 ]
#  [0.40921468 0.1318916  0.4588938 ]
#  [0.40192735 0.15207408 0.44599858]]
# Example Validation Predictions:
# [[0.39534098 0.12018798 0.48447114]
#  [0.35475236 0.3477104  0.2975372 ]
#  [0.35117522 0.34359154 0.30523327]
#  ...
#  [0.3995225  0.13358216 0.46689534]
#  [0.3945666  0.11494414 0.49048936]
#  [0.4088824  0.13395375 0.45716378]]

# %%
visualizeConfusion(dirname, filebase)
# Out:
# 0.7594832626288672

# %% [markdown]
# ## Experiment 3

# %%
dirname = 'results_hw4'
filebase = 'image_None_hidden_50_20_Csize_3_3_3_3_3_Cfilters_10_20_30_40_50_Pool_2_2_2_2_2_drop_0.50_L2_0.001000_ntrain_04_rot_*_results.pkl'
visualizeExperiment(dirname, filebase)
# Out:
# Average Val Accuracy:
# 0.5696800351142883
# Example Training Predictions:
# [[0.32439747 0.3835821  0.29202047]
#  [0.32339352 0.37902704 0.29757947]
#  [0.3237021  0.3841248  0.29217312]
#  ...
#  [0.3112596  0.3266572  0.36208323]
#  [0.32469317 0.33292127 0.34238553]
#  [0.30893472 0.3608521  0.33021322]]
# Example Validation Predictions:
# [[0.28049707 0.38634312 0.33315977]
#  [0.3188244  0.38570404 0.2954715 ]
#  [0.31550527 0.38862902 0.2958657 ]
#  ...
#  [0.34611332 0.31821486 0.33567187]
#  [0.3455197  0.295951   0.35852933]
#  [0.3450011  0.3238989  0.33109993]]

# %%
visualizeConfusion(dirname, filebase)
# Out:
# 0.7426178540250821

# %% [markdown]
# # Deep Experiment #4

# %%
dirname = 'results_hw4'
filebase = 'image_None_hidden_75_30_10_5_Csize_3_3_3_3_3_3_3_3_Cfilters_10_20_30_40_50_60_70_80_Pool_1_2_1_2_1_2_1_2_drop_0.50_L2_0.000010_ntrain_04_rot_*_results.pkl'
visualizeExperiment(dirname, filebase)
# Out:
# Average Val Accuracy:
# 0.6145439863204956
# Example Training Predictions:
# [[0.31392527 0.34217644 0.34389836]
#  [0.31060714 0.35852173 0.3308712 ]
#  [0.30824396 0.3686466  0.32310942]
#  ...
#  [0.30569145 0.37950286 0.31480563]
#  [0.30828035 0.3664071  0.32531258]
#  [0.30205166 0.39320648 0.30474186]]
# Example Validation Predictions:
# [[0.2878123  0.44227725 0.26991045]
#  [0.30266106 0.39627835 0.30106056]
#  [0.3039523  0.3948422  0.3012055 ]
#  ...
#  [0.3229992  0.29739845 0.37960234]
#  [0.32444662 0.28927    0.38628334]
#  [0.32279554 0.30864704 0.3685574 ]]

# %%
visualizeConfusion(dirname, filebase)
# Out:
# 0.6983875378763942

# %%
dirname = 'results_hw4'
filebase = 'image_None_hidden_75_30_10_5_Csize_3_5_5_5_5_5_5_Cfilters_10_20_30_40_50_60_70_Pool_1_2_1_2_1_2_2_drop_0.50_L2_0.000100_ntrain_04_rot_*_results.pkl'
visualizeExperiment(dirname, filebase)
# Out:
# Average Val Accuracy:
# 0.5494858622550964
# Example Training Predictions:
# [[0.38218164 0.28094473 0.33687362]
#  [0.34950298 0.34611288 0.3043841 ]
#  [0.3879418  0.26040417 0.351654  ]
#  ...
#  [0.37589222 0.24530815 0.37879968]
#  [0.3745507  0.26431286 0.36113647]
#  [0.36768022 0.28111255 0.3512073 ]]
# Example Validation Predictions:
# [[0.2569174  0.50225717 0.24082544]
#  [0.29672462 0.4407322  0.26254317]
#  [0.36744213 0.32571274 0.30684513]
#  ...
#  [0.37228385 0.23134689 0.39636925]
#  [0.37997553 0.23050022 0.38952425]
#  [0.37581438 0.23243664 0.39174902]]

# %%
visualizeConfusion(dirname, filebase)
# Out:
# 0.6817527887569321

# %%
dirname = 'results_hw4'
filebase = 'image_None_hidden_100_50_20_Csize_3_5_5_Cfilters_10_20_30_Pool_2_2_2_drop_0.50_L2_0.001000_ntrain_04_rot_*_results.pkl'
visualizeExperiment(dirname, filebase)
visualizeConfusion(dirname, filebase)
# Out:
# Average Val Accuracy:
# 0.5419746816158295
# Example Training Predictions:
# [[0.6868795  0.03739084 0.27572963]
#  [0.66503954 0.07099308 0.26396742]
#  [0.7717864  0.03157634 0.1966372 ]
#  ...
#  [0.5048232  0.02662263 0.46855417]
#  [0.6270489  0.01760618 0.35534495]
#  [0.64969826 0.01858414 0.33171764]]
# Example Validation Predictions:
# [[0.21036753 0.34378743 0.44584513]
#  [0.10938454 0.81357026 0.07704525]
#  [0.28303182 0.61511093 0.10185719]
#  ...
#  [0.81926274 0.02410538 0.15663196]
#  [0.67370987 0.03470744 0.29158276]
#  [0.7502928  0.00987237 0.2398349 ]]
# 0.7653633775682741

# %%
dirname = 'results_hw4'
filebase = 'image_None_hidden_100_50_20_Csize_3_5_5_Cfilters_10_20_30_Pool_2_2_2_drop_0.50_L2_0.010000_ntrain_04_rot_*_results.pkl'
visualizeExperiment(dirname, filebase)
visualizeConfusion(dirname, filebase)
# Out:
# Average Val Accuracy:
# 0.38450632989406586
# Example Training Predictions:
# [[0.55918974 0.11783434 0.32297587]
#  [0.47302845 0.22396822 0.30300334]
#  [0.59476465 0.07728633 0.3279491 ]
#  ...
#  [0.53023535 0.0886853  0.38107935]
#  [0.5157484  0.10446188 0.37978974]
#  [0.46041557 0.15148377 0.3881006 ]]
# Example Validation Predictions:
# [[0.08933095 0.7527573  0.1579117 ]
#  [0.30943766 0.4279062  0.2626561 ]
#  [0.5015516  0.18518946 0.3132589 ]
#  ...
#  [0.5054889  0.07823848 0.41627264]
#  [0.5748359  0.05232259 0.37284154]
#  [0.6037186  0.03328261 0.3629988 ]]
# 0.6384923835982808

# %%
dirname = 'results_hw4'
filebase = 'image_None_hidden_100_50_20_Csize_3_5_5_Cfilters_10_20_30_Pool_2_2_2_drop_0.50_L2_0.005000_ntrain_04_rot_*_results.pkl'
visualizeExperiment(dirname, filebase)
visualizeConfusion(dirname, filebase)
# Out:
# Average Val Accuracy:
# 0.4367594927549362
# Example Training Predictions:
# [[0.5901094  0.06447271 0.34541783]
#  [0.5530813  0.10472709 0.3421917 ]
#  [0.6181019  0.05263036 0.32926777]
#  ...
#  [0.46259868 0.0742766  0.4631247 ]
#  [0.4958815  0.07170664 0.43241182]
#  [0.47724116 0.09023096 0.43252787]]
# Example Validation Predictions:
# [[0.19152935 0.38623932 0.4222314 ]
#  [0.35921985 0.35663274 0.28414744]
#  [0.5225585  0.20780115 0.26964033]
#  ...
#  [0.38314152 0.22757587 0.38928255]
#  [0.4386141  0.12347326 0.4379126 ]
#  [0.49165738 0.06085762 0.44748503]]
# 0.6467566814695931

# %%
dirname = 'results_hw4'
filebase = 'image_None_hidden_100_50_20_Csize_3_5_5_Cfilters_10_20_30_Pool_2_2_2_drop_0.50_L2_0.002500_ntrain_04_rot_*_results.pkl'
visualizeExperiment(dirname, filebase)
visualizeConfusion(dirname, filebase)
# Out:
# Average Val Accuracy:
# 0.43934177458286283
# Example Training Predictions:
# [[0.4450473  0.18272842 0.37222433]
#  [0.3244717  0.37735638 0.2981719 ]
#  [0.5682487  0.08164009 0.35011128]
#  ...
#  [0.4020008  0.06320485 0.5347944 ]
#  [0.40830716 0.07924185 0.51245093]
#  [0.413392   0.07319939 0.51340854]]
# Example Validation Predictions:
# [[0.06306212 0.6045967  0.33234128]
#  [0.09151252 0.7654166  0.1430709 ]
#  [0.128825   0.75768375 0.11349127]
#  ...
#  [0.3710672  0.08613453 0.5427982 ]
#  [0.4274191  0.0636367  0.5089442 ]
#  [0.44050592 0.04044862 0.51904553]]
# 0.6759763952273424

# %%
## BEST
dirname = 'results_hw4'
filebase = 'image_None_hidden_100_50_20_Csize_3_5_5_Cfilters_10_20_30_Pool_2_2_2_drop_0.50_L2_0.000500_ntrain_04_rot_*_results.pkl'
visualizeExperiment(dirname, filebase)
visualizeConfusion(dirname, filebase)
# Out:
# Average Val Accuracy:
# 0.5730632901191711
# Example Training Predictions:
# [[0.67823774 0.01474986 0.30701235]
#  [0.67753416 0.02653955 0.29592633]
#  [0.75034446 0.01040338 0.2392522 ]
#  ...
#  [0.48149544 0.00521708 0.5132875 ]
#  [0.5580872  0.00465484 0.4372579 ]
#  [0.5414173  0.00756734 0.45101535]]
# Example Validation Predictions:
# [[0.21432662 0.13951467 0.6461587 ]
#  [0.22366959 0.6639797  0.11235074]
#  [0.2596954  0.63870054 0.10160401]
#  ...
#  [0.84367126 0.00675841 0.14957038]
#  [0.70059496 0.00533032 0.29407468]
#  [0.7227729  0.00352662 0.27370045]]
# 0.7849269143765403

# %%
dirname = 'results_hw4'
filebase = 'image_None_hidden_100_50_20_Csize_3_5_5_Cfilters_10_20_30_Pool_2_2_2_drop_0.50_L2_0.000250_ntrain_04_rot_*_results.pkl'
visualizeExperiment(dirname, filebase)
visualizeConfusion(dirname, filebase)
# Out:
# Average Val Accuracy:
# 0.4245063245296478
# Example Training Predictions:
# [[0.65899646 0.02009703 0.32090655]
#  [0.6790641  0.02542081 0.2955151 ]
#  [0.7178783  0.01733408 0.2647876 ]
#  ...
#  [0.38054687 0.03015801 0.58929515]
#  [0.4117261  0.02892988 0.559344  ]
#  [0.4052757  0.03761038 0.5571138 ]]
# Example Validation Predictions:
# [[0.1069577  0.37120435 0.52183795]
#  [0.05757221 0.9088129  0.03361497]
#  [0.13187486 0.8293168  0.03880842]
#  ...
#  [0.36179376 0.16793953 0.47026676]
#  [0.38049003 0.04127548 0.57823443]
#  [0.4037169  0.02286051 0.57342255]]
# 0.6212878742316225

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-ad41d441b4f5> in <module>
# ----> 1 tf.config.threading.get_inter_op_parallelism_threads()
#       2
#
# NameError: name 'tf' is not defined

# %%
dirname = 'results_hw4'
filebase = 'image_None_hidden_100_50_20_Csize_3_5_5_Cfilters_10_20_30_Pool_2_2_2_drop_0.50_L2_0.000500_ntrain_04_rot_*_results.pkl'
visualizeExperiment(dirname, filebase)
visualizeConfusion(dirname, filebase)
# Out:
# Average Val Accuracy:
# 0.6785299897193908
# Example Training Predictions:
# [[0.6223944  0.05189913 0.32570654]
#  [0.66835684 0.04307366 0.28856948]
#  [0.8022594  0.02884488 0.16889569]
#  ...
#  [0.3843918  0.0200247  0.5955835 ]
#  [0.56861955 0.01915191 0.41222852]
#  [0.58202744 0.02029386 0.39767876]]
# Example Validation Predictions:
# [[0.2147501  0.10843991 0.67681   ]
#  [0.5839964  0.24300863 0.17299491]
#  [0.7472375  0.11321434 0.1395482 ]
#  ...
#  [0.9013805  0.01419932 0.08442017]
#  [0.7746505  0.00932287 0.21602671]
#  [0.7609423  0.01319664 0.22586115]]
# 0.7643611106259567

# %%
dirname = 'results_hw4'
filebase = 'image_None_hidden_100_30_Csize_3_5_5_Cfilters_10_20_30_Pool_2_2_2_drop_0.50_L2_0.001000_ntrain_04_rot_*_results.pkl'
visualizeExperiment(dirname, filebase)
visualizeConfusion(dirname, filebase)
# Out:
# Average Val Accuracy:
# 0.6866998076438904
# Example Training Predictions:
# [[4.44111139e-01 3.68986977e-04 5.55519879e-01]
#  [4.97370601e-01 1.78214585e-04 5.02451181e-01]
#  [9.02907372e-01 5.15309548e-05 9.70411003e-02]
#  ...
#  [6.44450486e-01 1.25266815e-05 3.55536968e-01]
#  [3.28184366e-01 9.55078212e-05 6.71720088e-01]
#  [4.89579171e-01 8.61427470e-05 5.10334671e-01]]
# Example Validation Predictions:
# [[7.3844153e-01 7.0577987e-02 1.9098040e-01]
#  [9.5431888e-01 2.1600071e-02 2.4081016e-02]
#  [4.4992629e-01 4.5818135e-01 9.1892339e-02]
#  ...
#  [9.7302568e-01 7.9480542e-06 2.6966376e-02]
#  [8.6173886e-01 4.5477704e-05 1.3821563e-01]
#  [7.5715566e-01 3.3104312e-05 2.4281117e-01]]
# 0.8621769559657938

# %%
dirname = 'results_hw4'
filebase = 'image_rep2_hidden_100_30_Csize_3_5_5_Cfilters_10_20_30_Pool_2_2_2_drop_0.50_L2_0.001000_ntrain_04_rot_*_results.pkl'
visualizeExperiment(dirname, filebase)
visualizeConfusion(dirname, filebase)
# Out:
# Average Val Accuracy:
# 0.7021727800369263
# Example Training Predictions:
# [[4.0691620e-01 2.0038829e-05 5.9306377e-01]
#  [3.6643699e-01 8.0956299e-05 6.3348204e-01]
#  [8.1206918e-01 2.8797336e-05 1.8790208e-01]
#  ...
#  [1.9319789e-01 4.7689709e-06 8.0679739e-01]
#  [7.2957307e-02 6.2106876e-04 9.2642164e-01]
#  [9.5690504e-02 3.6993384e-05 9.0427256e-01]]
# Example Validation Predictions:
# [[7.3176599e-01 8.6547799e-02 1.8168624e-01]
#  [9.9866557e-01 3.1197691e-04 1.0224360e-03]
#  [9.5550722e-01 1.1445121e-02 3.3047736e-02]
#  ...
#  [9.9875379e-01 4.1005963e-09 1.2461565e-03]
#  [8.4103233e-01 1.4999963e-05 1.5895256e-01]
#  [1.3065362e-01 3.7319653e-05 8.6930907e-01]]
# 0.8624200030312352

# %%
dirname = 'results_hw4'
filebase = 'image_deep_B_hidden_100_30_Csize_3_5_5_5_Cfilters_10_20_40_80_Pool_1_2_2_2_drop_0.50_L2_0.001000_ntrain_04_rot_*_results.pkl'
visualizeExperiment(dirname, filebase)
visualizeConfusion(dirname, filebase)
# Out:
# Average Val Accuracy:
# 0.705743670463562
# Example Training Predictions:
# [[9.9739540e-01 4.4548920e-11 2.6046368e-03]
#  [9.9952590e-01 4.5472319e-09 4.7415774e-04]
#  [9.9985981e-01 1.5429260e-11 1.4019936e-04]
#  ...
#  [1.5962179e-03 5.5822968e-10 9.9840385e-01]
#  [7.6570787e-04 3.5306735e-07 9.9923396e-01]
#  [3.6191967e-05 2.5160335e-07 9.9996352e-01]]
# Example Validation Predictions:
# [[9.1717726e-01 8.8359951e-04 8.1939004e-02]
#  [9.9999964e-01 6.9162582e-09 3.0365629e-07]
#  [5.9528172e-01 6.6152723e-03 3.9810306e-01]
#  ...
#  [9.9999535e-01 1.8982437e-08 4.6626415e-06]
#  [4.4003338e-02 1.0776643e-01 8.4823024e-01]
#  [1.7499853e-02 1.6083887e-04 9.8233932e-01]]
# Single AUC: 0.8914230529843081
# Single AUC: 0.7704057491704361
# Single AUC: 0.9376585618108982
# Single AUC: 0.8862258674057513
# Single AUC: 0.8496121063016299
# 0.8670650675346048
